# %%
import pandas as pd

# %%
from sklearn.datasets import make_moons,make_blobs
import matplotlib.pyplot as plt

# %%
X,y = make_blobs(n_features =2,n_samples=100,centers=6 ,random_state=42)

# %%
X.shape
# Out:
# (100, 2)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(6,n_init=1,random_state=42,max_iter=1)

# %%
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1,
#        n_clusters=6, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
model.cluster_centers_
# Out:
# array([[-6.84770403, -7.09318466],
#        [-2.81937737,  8.60427975],
#        [ 4.23249209,  1.42943726],
#        [-9.36970486,  8.51986604],
#        [ 4.61287021,  3.35718246],
#        [ 1.8949926 ,  4.26867309]])

# %%
model.labels_
# Out:
# array([3, 3, 1, 3, 3, 0, 2, 2, 4, 1, 1, 0, 3, 2, 4, 5, 3, 3, 0, 4, 5, 0,
#        1, 3, 5, 4, 3, 5, 3, 2, 0, 3, 5, 3, 5, 5, 1, 1, 1, 4, 0, 0, 4, 2,
#        5, 1, 2, 3, 5, 3, 3, 0, 0, 0, 4, 5, 5, 3, 1, 1, 0, 1, 3, 0, 3, 3,
#        3, 3, 3, 3, 5, 0, 3, 0, 3, 5, 2, 3, 5, 3, 3, 0, 3, 4, 3, 1, 5, 1,
#        1, 1, 3, 4, 0, 0, 3, 1, 3, 1, 4, 2])

# %%
plt.scatter(X[:,0],X[:,1],c = model.labels_)

for center in model.cluster_centers_:
    plt.scatter(center[0],center[1],s=120)
